# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

model = YOLO("yolov8.pt")
image = cv2.imread("/home/joshu/LPR-proj/data/LPRdatasets/plateImages/00a7d31c6cc6b7f3_jpg.rf.2707e63f5c51f113de704441ea210a65.jpg")
detector = VehicleDetector()
vehicles = detector.detect(image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       3 from ultralytics import YOLO
# ----> 5 model = YOLO("yolov8.pt")
#       6 image = cv2.imread("/home/joshu/LPR-proj/data/LPRdatasets/plateImages/00a7d31c6cc6b7f3_jpg.rf.2707e63f5c51f113de704441ea210a65.jpg")
#       7 detector = VehicleDetector()
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/ultralytics/models/yolo/model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# ...

# %%
print(f"Detected {len(vehicles)} vehicles")

for i, v in enumerate(vehicles):
    cv2.imshow(f"vehicle_{i}_{v['class']}", v["crop"])

cv2.waitKey(0)
cv2.destroyAllWindows()
